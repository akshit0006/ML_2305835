# %%
print('MACHINE LEARNING');
# Out:
# MACHINE LEARNING

# %%
for i in range (1,10):
    print('LOOP');
# Out:
# LOOP
# LOOP
# LOOP
# LOOP
# LOOP
# LOOP
# LOOP
# LOOP
# LOOP

# %%
n=5
f=0
for i in range (2,n-1):
    if n%i==0:
        print("Not prime")
        break
else:
    print('Prime')
# Out:
# Prime

# %%
import pandas as pd

# %%
student= pd.read_csv('CSV1.csv')

# %%
student.head(2)
# Out:
#   Name,\tSection, \tMarks,\tRoll,\tGrade
# 0               Asmit,\tA,\t89,\t101,\tA
# 1                 Omm,\tA,\t80,\t116,\tA

# %%
student= pd.read_csv('Students.csv')

# %%
student.head(2)
# Out:
#      Name\t Section  Marks, Roll, Grade
# 0  Asmit,\t       A,    89,  101,     A
# 1    Omm,\t       A,    80,  116,     A

# %%
student.head()
# Out:
#        Name\t Section  Marks, Roll, Grade
# 0    Asmit,\t       A,    89,  101,     A
# 1      Omm,\t       A,    80,  116,     A
# 2  Manisha,\t       B,    73,  187,     B
# 3      Rinku,       C,    95,  213,    A+
# 4    Jennifer       B,    63,  175,     C

# %%
student.columns
# Out:
# Index(['Name\t', 'Section ', 'Marks,', 'Roll,', 'Grade'], dtype='object')
